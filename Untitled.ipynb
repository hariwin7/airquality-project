# %%
import requests
import pandas as pd

# %%
response = requests.get("https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=579b464db66ec23bdd0000010d3e712f7eb7429b6f9d6e9d9d015920&format=json&offset=0&limit=500")

# %%
res=response.json()
res
# Out:
# {u'active': u'1',
#  u'catalog_uuid': u'a3e7afc6-b799-4ede-b143-8e074b27e0621',
#  u'count': 500,
#  u'created': 1543320551,
#  u'created_date': u'2018-11-27T17:39:11Z',
#  u'desc': u'Real time Air Quality Index from various location',
#  u'field': [{u'id': u'id', u'name': u'id', u'type': u'double'},
#   {u'id': u'country', u'name': u'country', u'type': u'keyword'},
#   {u'id': u'state', u'name': u'state', u'type': u'keyword'},
#   {u'id': u'city', u'name': u'city', u'type': u'keyword'},
#   {u'id': u'station', u'name': u'station', u'type': u'keyword'},
#   {u'id': u'last_update', u'name': u'last_update', u'type': u'date'},
#   {u'id': u'pollutant_id', u'name': u'pollutant_id', u'type': u'keyword'},
#   {u'id': u'pollutant_min', u'name': u'pollutant_min', u'type': u'double'},
#   {u'id': u'pollutant_max', u'name': u'pollutant_max', u'type': u'double'},
#   {u'id': u'pollutant_avg', u'name': u'pollutant_avg', u'type': u'double'},
# ...

# %%
data =[ rec for rec in res['records'] if rec['city']=="Delhi"]

# %%
keys = data[0].keys()

# %%
for dat in data:
    for key,value in dat.iteritems():
        if key==keys[0]:
            print key,value
# Out:
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# city Delhi
# ...

# %%
pollu_data = pd.read_csv("data.csv")
# Out:
# /home/keltron/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
testdat=pollu_data[pollu_data[u'state']=="Delhi"]
testdat[testdat[u'date'].str.contains('1987',na=False)]
# Out:
#       stn_code sampling_date  state location                           agency  \
# 65861       60      9/1/1987  Delhi    Delhi  Central Pollution Control Board
# 65862       59      9/2/1987  Delhi    Delhi  Central Pollution Control Board
# 65863       58      9/3/1987  Delhi    Delhi  Central Pollution Control Board
# 65864       57      9/3/1987  Delhi    Delhi  Central Pollution Control Board
# 65865       56      9/2/1987  Delhi    Delhi  Central Pollution Control Board
# 65866       55      9/2/1987  Delhi    Delhi  Central Pollution Control Board
# 65867       60     10/3/1987  Delhi    Delhi  Central Pollution Control Board
# 65868       59     10/4/1987  Delhi    Delhi  Central Pollution Control Board
# 65869       58     10/1/1987  Delhi    Delhi  Central Pollution Control Board
# 65870       57     10/1/1987  Delhi    Delhi  Central Pollution Control Board
# 65871       56     10/3/1987  Delhi    Delhi  Central Pollution Control Board
# ...

# %%
from datetime import datetime
datetime_object=[]
for date in testdat[u'date']:
    datetime_object.append(datetime.strptime(date, '%Y-%m-%d'))

# %%
datetime_object[0]
# Out:
# datetime.datetime(1987, 1, 9, 0, 0)

# %%
dt1 = datetime.strptime(testdat.iloc[0][u'date'], '%Y-%m-%d')
dt2 = datetime.strptime(testdat.iloc[1][u'date'], '%Y-%m-%d')

# %%
dt1==datetime(1987, 1, 9, 0, 0)
# Out:
# True

# %%
type(testdat.iloc[0][u'sampling_date'])
# Out:
# str
